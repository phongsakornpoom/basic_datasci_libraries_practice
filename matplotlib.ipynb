# %%
import matplotlib as mpl
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn')
fig = plt.figure()
ax = plt.axes()

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
x=np.linspace(0,10,100)
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))
plt.show
fig=plt.figure(0)#create new figure name it 0
fig.savefig('sample.png')

# %%
plt.style.use('seaborn')
plt.figure()
plt.subplot(3,1,1)#row,column,index need to be between row and column. index indicate what row or column it is plotted on
plt.plot(x,np.sin(x))
plt.subplot(3,1,2)
plt.plot(x,np.cos(x))
plt.subplot(3,1,3)
plt.plot(x,np.tan(x))

# %%
#this one operate by subplots with s at the end
fig,ax=plt.subplots(3)#define the row to 3 because column is default as one
ax[0].plot(x,np.sin(x))
ax[1].plot(x,np.cos(x))
ax[2].plot(x,np.tan(x))

# %%
plt.figure()
plt.plot(x,np.sin(x),color='green',linestyle='dashed')
plt.plot(x,np.sin(x-1),color='red',linestyle='solid')
plt.xlim(0,4)
plt.ylim(0.25,1)
# Out:
# (0.25, 1)

# %%
plt.figure()
plt.plot(x,np.sin(x),color='green',linestyle='dashed',label='sinx')
plt.plot(x,np.sin(x-1),color='red',linestyle='solid',label='sinx-1')
plt.axis('equal')
plt.title('simple lineplot')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()

# %%
plt.style.use('seaborn-whitegrid')
x=np.linspace(0,10,30)
y=np.sin(x)
plt.plot(x,y,'o',color='black')

# %%
for marker in['o','.','x','v','+','<','>','s','d']:
    plt.plot(np.random.rand(5),np.random.rand(5),marker,label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0,1.8);

# %%
plt.plot(x,y,'-p',color='gray',markersize=15,linewidth=4,markerfacecolor='white',markeredgewidth=2)
plt.ylim(-1.2,1.2)
# Out:
# (-1.2, 1.2)

# %%
plt.scatter(x,y,marker='o',cmap='cold')

# %%
z=np.random.randn(100)
w=np.random.randn(100)
colors=np.random.rand(100)
size=1000*np.random.rand(100)
plt.scatter(z,w,s=size,c=colors,cmap='hot',alpha=0.8)
plt.colorbar()

# %%
x=np.linspace(0,10,50)
dy=0.8
y=np.sin(x)+dy*np.random.randn(50)
plt.errorbar(x,y,yerr=dy,fmt='.k')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.style.use('seaborn-white')
def f(x,y):
    return np.sin(x)**10+np.cos(10+y*x)*np.cos(x)
x=np.linspace(0,5,50)
y=np.linspace(0,5,40)
X,Y=np.meshgrid(x,y)#change dimension to be the same grid
Z=f(X,Y)
plt.contour(X,Y,Z,color='black')
# Out:
# C:\Users\pongsakorn tanupatra\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: The following kwargs were not used by contour: 'color'

# %%
plt.contour(X,Y,Z,20,cmap='RdGy')

# %%
plt.contourf(X,Y,Z,20,cmap='RdGy')
plt.colorbar()

# %%
x=np.array([1,1,2,4,5])
plt.hist(x,bins=10)
plt.xlabel('age')
# Out:
# Text(0.5, 0, 'age')

# %%
x1=np.random.normal(0,0.8,1000)
x2=np.random.normal(-2,1,1000)
x3=np.random.normal(3,2,1000)
kwargs=dict(histtype='stepfilled',alpha=0.3,normed=True,bins=40)
plt.hist(x1,**kwargs)
plt.hist(x2,**kwargs)
plt.hist(x3,**kwargs)
# Out:
# C:\Users\pongsakorn tanupatra\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   """
# C:\Users\pongsakorn tanupatra\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#
# C:\Users\pongsakorn tanupatra\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   import sys
# (array([0.00325058, 0.00325058, 0.00650117, 0.00325058, 0.00650117,
#         0.00975175, 0.02275408, 0.04875875, 0.03575641, 0.0585105 ,
#         0.07801399, 0.11702099, 0.09426691, 0.1527774 , 0.14302565,
#         0.18203265, 0.17553149, 0.2307914 , 0.21778907, 0.16577974,
# ...

# %%
plt.style.use('classic')
fig,ax=plt.subplots()
x=np.linspace(0,10,1000)
ax.plot(x,np.sin(x),'-r',label='sin')
ax.plot(x,np.cos(x),'--c',label='cos')
ax.axis('equal')
ax.legend(loc='lower left',frameon=False)

# %%
ax.legend(loc='lower center',frameon=False,ncol=2)
fig

# %%
ax.legend(fancybox=True,framealpha=1,shadow=True,borderpad=1)
ax.axis('equal')
fig

# %%
fig1,sub=plt.subplots(2,3)
sub[0,0].plot(x,np.sin(x))
sub[0,1].plot(x,np.cos(x),'--g')
sub[0,2].plot(x,np.tan(x),'-r')
sub[1,0].scatter(z,w,marker='o')
sub[1,1].scatter(z,w,marker='+',color='orange')
sub[1,2].scatter(z,w,marker='d',color='green')

# %%
fig=plt.figure()
fig.subplots_adjust(hspace=0.4,wspace=0.6)
for i in range(1,7):
    ax=fig.add_subplot(2,3,i)
    ax.text(0.5,0.5,str((2,3,i)),
    fontsize=18,ha='center')

# %%
grid=plt.GridSpec(2,3,wspace=0.2,hspace=0.3)
plt.subplot(grid[0,0])
plt.subplot(grid[0,1:])
plt.subplot(grid[1,:2])
plt.subplot(grid[1,2])

# %%
ax=plt.axes()
ax.plot(np.random.rand(50))
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %%
fig,ax=plt.subplots(4,4, sharex=True,sharey=True)
for axi in ax.flat:
    axi.xaxis.set_major_locator(plt.MaxNLocator(3))
    axi.yaxis.set_major_locator(plt.MaxNLocator(3))

# %%
fig3,barr=plt.subplots()
movie=np.array(['naruto','dragonball','conan'])
rating=np.array([20,40,100])
barr.bar(movie,rating,color='orange')
# Out:
# <BarContainer object of 3 artists>

# %%
x=np.random.randn(1000)
from matplotlib import cycler
colors=cycler('color',
              ['#EE6666','#3388BB','#9988DD',
               '#EECC55','#88BB44','FFBBBB'])
plt.rc('axes',facecolor='#3388BB', edgecolor='orange',
       axisbelow=True,grid=True,prop_cycle=colors)
plt.rc('grid',color='purple',linestyle='dashed')
plt.rc('ytick',direction='out',color='blue')
plt.rc('xtick',direction='out',color='white')
plt.rc('lines',linewidth=3)
plt.hist(x,bins=10,color='orange')
# Out:
# (array([  7.,  45., 126., 229., 292., 188.,  78.,  30.,   4.,   1.]),
#  array([-3.01442595, -2.3036772 , -1.59292844, -0.88217969, -0.17143093,
#          0.53931782,  1.25006658,  1.96081533,  2.67156409,  3.38231284,
#          4.0930616 ]),
#  <a list of 10 Patch objects>)

# %%
from mpl_toolkits import mplot3d

# %%
ax=plt.axes(projection='3d')
zline=np.linspace(0,15,1000)
xline=np.sin(zline)
yline=np.cos(zline)
ax.plot3D(xline,yline,zline,'-c')

zdata=15*np.random.random(100)
xdata=np.sin(zdata)+0.1*np.random.randn(100)
ydata=np.cos(zdata)+0.1*np.random.randn(100)
ax.scatter3D(xdata,ydata,c=zdata,cmap='hot')

# %%
import seaborn as sns
plt.style.use('classic')
sns.set()
x=np.linspace(0,10,500)
y=np.cumsum(np.random.randn(500,6),0)
plt.plot(x,y)
plt.legend('ABCDEF',ncol=2,loc='upper left')

# %%
fig

# %%
plt.style.use('classic')
with plt.style.context('seaborn'):
    plt.plot(x,y)

# %%
plt.plot(x,y)

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,hue='species', height=2.5)

# %%
tip=sns.load_dataset('tips')
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tip['tip_pct']=100*tip['tip']/tip['total_bill']
grid=sns.FacetGrid(tip,row="sex",col="time",margin_titles=True)
grid.map(plt.hist,"tip_pct",bins=np.linspace(0,40,15))

# %%
with sns.axes_style(style='ticks'):
    g=sns.catplot("day","total_bill","sex",data=tip,kind="box")
    g.set_axis_labels("Day","Total Bill")
